# %%
import numpy as np
import seaborn as sns
from scipy.io import loadmat
from scipy import interpolate
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# %%
learned_graphs = np.load('./Outputs/graph_plot_learned_graph.npy')
ground_truth_adj = np.array(loadmat('./Adj.mat')['A_Ground'])
flattened_adj = ground_truth_adj.flatten()

print(learned_graphs.shape)
# Out:
# (160000, 20, 20)

# %%
sensing_ratio = 1 + np.arange(80)
n_sensing = len(sensing_ratio)

epochs = 20
n_data = 100
n_pts = epochs * n_data

# %%
def smooth_curve(x, y, smooth_factor):
    spline = interpolate.UnivariateSpline(x, y)
    spline.set_smoothing_factor(smooth_factor)
    return spline(x)

# %%
def laplacian_to_adj(laplacian, threshold):
    adjacency = -(laplacian - (np.eye(ground_truth_adj.shape[0]) * laplacian))
    
    tmp_adj = np.sign(adjacency - threshold)
    tmp_adj[tmp_adj < 0] = 0.0
    return tmp_adj

# %%
f1_scores_plot = []
avg_f1_scores_plot = []
learned_lap_graphs = []

for n_psi, sen in enumerate(sensing_ratio):
    all_graphs = learned_graphs[n_psi * n_pts : (n_psi + 1) * n_pts, : , :]
    graphs = all_graphs[-n_data : , : , :]
    
    learned_lap_graphs.append(graphs)
    
    f1_scores = []
    adj_graphs = []
    
    s = int(np.sqrt(n_data))
    f_score_matrix = np.zeros(n_data)
    
    for i in range(n_data):
        adj_graph = laplacian_to_adj(graphs[i, : , :], 0.0)
        adj_graphs.append(adj_graph.flatten())
        f1_scores.append(f1_score(flattened_adj, adj_graphs[-1]))
    
    compare_graph = adj_graphs[0]
    for i, graph_1 in enumerate(adj_graphs):
        f_score_matrix[i] = f1_score(compare_graph, graph_1)
    
    print(f"For {sen}% sensing ratio:")
    
#     ax = sns.heatmap(f_score_matrix.reshape([s, s]), vmin = 0.0, vmax = 1.0)
#     plt.title("F-Score among graphs")
#     plt.show()
    
    avg_f_score = np.sum(f_score_matrix) / (n_data)
    avg_f1_scores_plot.append(avg_f_score)
    
    print(f"\nAverage F-Score among entries: {avg_f_score:.5f}")
    print(f"Average F-Score with Ground Truth graph: {np.average(f1_scores):.5f}\n\n")
    f1_scores_plot.append(np.average(f1_scores))
# Out:
# For 1% sensing ratio:
#
# Average F-Score among entries: 0.99819
# Average F-Score with Ground Truth graph: 0.85383
#
#
# For 2% sensing ratio:
#
# Average F-Score among entries: 0.99505
# Average F-Score with Ground Truth graph: 0.85195
#
#
# For 3% sensing ratio:
#
# Average F-Score among entries: 0.98660
# Average F-Score with Ground Truth graph: 0.84776
#
#
# For 4% sensing ratio:
#
# Average F-Score among entries: 0.96466
# Average F-Score with Ground Truth graph: 0.84199
#
#
# For 5% sensing ratio:
#
# Average F-Score among entries: 0.95972
# Average F-Score with Ground Truth graph: 0.83511
#
#
# For 6% sensing ratio:
#
# Average F-Score among entries: 0.95152
# Average F-Score with Ground Truth graph: 0.82918
#
#
# For 7% sensing ratio:
#
# Average F-Score among entries: 0.95725
# Average F-Score with Ground Truth graph: 0.82436
#
#
# For 8% sensing ratio:
#
# Average F-Score among entries: 0.95847
# Average F-Score with Ground Truth graph: 0.81684
#
#
# For 9% sensing ratio:
#
# Average F-Score among entries: 0.93431
# Average F-Score with Ground Truth graph: 0.80974
#
#
# For 10% sensing ratio:
#
# Average F-Score among entries: 0.95072
# Average F-Score with Ground Truth graph: 0.80461
#
#
# For 11% sensing ratio:
#
# Average F-Score among entries: 0.95268
# Average F-Score with Ground Truth graph: 0.79765
#
#
# For 12% sensing ratio:
#
# Average F-Score among entries: 0.92540
# Average F-Score with Ground Truth graph: 0.79095
#
#
# For 13% sensing ratio:
#
# Average F-Score among entries: 0.93301
# Average F-Score with Ground Truth graph: 0.78552
#
#
# For 14% sensing ratio:
#
# Average F-Score among entries: 0.89288
# Average F-Score with Ground Truth graph: 0.78095
#
#
# For 15% sensing ratio:
#
# Average F-Score among entries: 0.91043
# Average F-Score with Ground Truth graph: 0.77500
#
#
# For 16% sensing ratio:
#
# Average F-Score among entries: 0.93270
# Average F-Score with Ground Truth graph: 0.77146
#
#
# For 17% sensing ratio:
#
# Average F-Score among entries: 0.87321
# Average F-Score with Ground Truth graph: 0.76648
#
#
# For 18% sensing ratio:
#
# Average F-Score among entries: 0.91796
# Average F-Score with Ground Truth graph: 0.76042
#
#
# For 19% sensing ratio:
#
# Average F-Score among entries: 0.91522
# Average F-Score with Ground Truth graph: 0.75571
#
#
# For 20% sensing ratio:
#
# Average F-Score among entries: 0.90981
# Average F-Score with Ground Truth graph: 0.75070
#
#
# For 21% sensing ratio:
#
# Average F-Score among entries: 0.89956
# Average F-Score with Ground Truth graph: 0.74604
#
#
# For 22% sensing ratio:
#
# Average F-Score among entries: 0.89148
# Average F-Score with Ground Truth graph: 0.73952
#
#
# For 23% sensing ratio:
#
# Average F-Score among entries: 0.89344
# Average F-Score with Ground Truth graph: 0.73780
#
#
# For 24% sensing ratio:
#
# Average F-Score among entries: 0.89912
# Average F-Score with Ground Truth graph: 0.73330
#
#
# For 25% sensing ratio:
#
# Average F-Score among entries: 0.90220
# Average F-Score with Ground Truth graph: 0.73307
#
#
# For 26% sensing ratio:
#
# Average F-Score among entries: 0.87247
# Average F-Score with Ground Truth graph: 0.72742
#
#
# For 27% sensing ratio:
#
# Average F-Score among entries: 0.87677
# Average F-Score with Ground Truth graph: 0.72493
#
#
# For 28% sensing ratio:
#
# Average F-Score among entries: 0.88041
# Average F-Score with Ground Truth graph: 0.72136
#
#
# For 29% sensing ratio:
#
# Average F-Score among entries: 0.89453
# Average F-Score with Ground Truth graph: 0.72042
#
#
# For 30% sensing ratio:
#
# Average F-Score among entries: 0.89342
# Average F-Score with Ground Truth graph: 0.71811
#
#
# For 31% sensing ratio:
#
# Average F-Score among entries: 0.88774
# Average F-Score with Ground Truth graph: 0.71324
#
#
# For 32% sensing ratio:
#
# Average F-Score among entries: 0.90685
# Average F-Score with Ground Truth graph: 0.71450
#
#
# For 33% sensing ratio:
#
# Average F-Score among entries: 0.88932
# Average F-Score with Ground Truth graph: 0.70816
#
#
# For 34% sensing ratio:
#
# Average F-Score among entries: 0.89950
# Average F-Score with Ground Truth graph: 0.70828
#
#
# For 35% sensing ratio:
#
# Average F-Score among entries: 0.89330
# Average F-Score with Ground Truth graph: 0.70634
#
#
# For 36% sensing ratio:
#
# Average F-Score among entries: 0.90135
# Average F-Score with Ground Truth graph: 0.69910
#
#
# For 37% sensing ratio:
#
# Average F-Score among entries: 0.89100
# Average F-Score with Ground Truth graph: 0.69866
#
#
# For 38% sensing ratio:
#
# Average F-Score among entries: 0.89750
# Average F-Score with Ground Truth graph: 0.69737
#
#
# For 39% sensing ratio:
#
# Average F-Score among entries: 0.90676
# Average F-Score with Ground Truth graph: 0.69603
#
#
# For 40% sensing ratio:
#
# Average F-Score among entries: 0.87931
# Average F-Score with Ground Truth graph: 0.69083
#
#
# For 41% sensing ratio:
#
# Average F-Score among entries: 0.89597
# Average F-Score with Ground Truth graph: 0.68985
#
#
# For 42% sensing ratio:
#
# Average F-Score among entries: 0.89078
# Average F-Score with Ground Truth graph: 0.68439
#
#
# For 43% sensing ratio:
#
# Average F-Score among entries: 0.88833
# Average F-Score with Ground Truth graph: 0.68447
#
#
# For 44% sensing ratio:
#
# Average F-Score among entries: 0.86596
# Average F-Score with Ground Truth graph: 0.68509
#
#
# For 45% sensing ratio:
#
# Average F-Score among entries: 0.89308
# Average F-Score with Ground Truth graph: 0.68215
#
#
# For 46% sensing ratio:
#
# Average F-Score among entries: 0.87474
# Average F-Score with Ground Truth graph: 0.68088
#
#
# For 47% sensing ratio:
#
# Average F-Score among entries: 0.86101
# Average F-Score with Ground Truth graph: 0.67782
#
#
# For 48% sensing ratio:
#
# Average F-Score among entries: 0.86419
# Average F-Score with Ground Truth graph: 0.67767
#
#
# For 49% sensing ratio:
#
# Average F-Score among entries: 0.88529
# Average F-Score with Ground Truth graph: 0.67519
#
#
# For 50% sensing ratio:
#
# Average F-Score among entries: 0.86001
# Average F-Score with Ground Truth graph: 0.67380
#
#
# For 51% sensing ratio:
#
# Average F-Score among entries: 0.88827
# Average F-Score with Ground Truth graph: 0.67458
#
#
# For 52% sensing ratio:
#
# Average F-Score among entries: 0.89354
# Average F-Score with Ground Truth graph: 0.67209
#
#
# For 53% sensing ratio:
#
# Average F-Score among entries: 0.89006
# Average F-Score with Ground Truth graph: 0.67077
#
#
# For 54% sensing ratio:
#
# Average F-Score among entries: 0.90461
# Average F-Score with Ground Truth graph: 0.66782
#
#
# For 55% sensing ratio:
#
# Average F-Score among entries: 0.87766
# Average F-Score with Ground Truth graph: 0.66700
#
#
# For 56% sensing ratio:
#
# Average F-Score among entries: 0.86895
# Average F-Score with Ground Truth graph: 0.66413
#
#
# For 57% sensing ratio:
#
# Average F-Score among entries: 0.88334
# Average F-Score with Ground Truth graph: 0.66261
#
#
# For 58% sensing ratio:
#
# Average F-Score among entries: 0.84190
# Average F-Score with Ground Truth graph: 0.66241
#
#
# For 59% sensing ratio:
#
# Average F-Score among entries: 0.90670
# Average F-Score with Ground Truth graph: 0.65901
#
#
# For 60% sensing ratio:
#
# Average F-Score among entries: 0.86253
# Average F-Score with Ground Truth graph: 0.65621
#
#
# For 61% sensing ratio:
#
# Average F-Score among entries: 0.86893
# Average F-Score with Ground Truth graph: 0.65363
#
#
# For 62% sensing ratio:
#
# Average F-Score among entries: 0.88458
# Average F-Score with Ground Truth graph: 0.65387
#
#
# For 63% sensing ratio:
#
# Average F-Score among entries: 0.80615
# Average F-Score with Ground Truth graph: 0.65247
#
#
# For 64% sensing ratio:
#
# Average F-Score among entries: 0.83985
# Average F-Score with Ground Truth graph: 0.65016
#
#
# For 65% sensing ratio:
#
# Average F-Score among entries: 0.85656
# Average F-Score with Ground Truth graph: 0.64935
#
#
# For 66% sensing ratio:
#
# Average F-Score among entries: 0.87311
# Average F-Score with Ground Truth graph: 0.64632
#
#
# For 67% sensing ratio:
#
# Average F-Score among entries: 0.88671
# Average F-Score with Ground Truth graph: 0.64683
#
#
# For 68% sensing ratio:
#
# Average F-Score among entries: 0.85295
# Average F-Score with Ground Truth graph: 0.64295
#
#
# For 69% sensing ratio:
#
# Average F-Score among entries: 0.86877
# Average F-Score with Ground Truth graph: 0.64249
#
#
# For 70% sensing ratio:
#
# Average F-Score among entries: 0.83385
# Average F-Score with Ground Truth graph: 0.63827
#
#
# For 71% sensing ratio:
#
# Average F-Score among entries: 0.84044
# Average F-Score with Ground Truth graph: 0.63453
#
#
# For 72% sensing ratio:
#
# Average F-Score among entries: 0.86792
# Average F-Score with Ground Truth graph: 0.63331
# For 73% sensing ratio:
#
# Average F-Score among entries: 0.85151
# Average F-Score with Ground Truth graph: 0.63203
#
#
# For 74% sensing ratio:
#
# Average F-Score among entries: 0.84622
# Average F-Score with Ground Truth graph: 0.62771
#
#
# For 75% sensing ratio:
#
# Average F-Score among entries: 0.84092
# Average F-Score with Ground Truth graph: 0.62483
#
#
# For 76% sensing ratio:
#
# Average F-Score among entries: 0.80366
# Average F-Score with Ground Truth graph: 0.62512
#
#
# For 77% sensing ratio:
#
# Average F-Score among entries: 0.80984
# Average F-Score with Ground Truth graph: 0.62269
#
#
# For 78% sensing ratio:
#
# Average F-Score among entries: 0.85056
# Average F-Score with Ground Truth graph: 0.61959
#
#
# For 79% sensing ratio:
#
# Average F-Score among entries: 0.85274
# Average F-Score with Ground Truth graph: 0.61642
#
#
# For 80% sensing ratio:
#
# Average F-Score among entries: 0.82781
# Average F-Score with Ground Truth graph: 0.61308

# %%
smooth_plot = smooth_curve(sensing_ratio, avg_f1_scores_plot, 0.2)

plt.plot(sensing_ratio, smooth_plot, 'b', lw = 3)
plt.plot(sensing_ratio, avg_f1_scores_plot, marker = "^")
plt.title(r"F-Score vs Sensing Ratio across different $\Psi$")
plt.xlabel("Sensing Ratio (in %)")
plt.ylabel("F-Score")
plt.grid()
# plt.savefig("./Plots/fscore_vs_sensing_ratio_among_graphs.png")
plt.show()

# %%
learned_lap_graphs = np.array(learned_lap_graphs)
f1_scores = []

for i_sen, rem in enumerate(sensing_ratio):
    graph_laplacians = np.squeeze(learned_lap_graphs[i_sen, :, :, :])
    avg_graph = np.sum(graph_laplacians, axis = 0) / graph_laplacians.shape[0]
    
    avg_graph_adj = laplacian_to_adj(avg_graph, 1.0)
    f1_scores.append(f1_score(flattened_adj, avg_graph_adj.flatten()))

# %%
smooth_plot_among_psi = smooth_curve(sensing_ratio, avg_f1_scores_plot, 0.5)
smooth_plot_ground_truth = smooth_curve(sensing_ratio, f1_scores_plot, 0.5)

ci = np.abs(np.array(smooth_plot_among_psi) - np.array(avg_f1_scores_plot))

ci = smooth_curve(sensing_ratio, ci, 0.01)
y = smooth_plot_among_psi

plt.plot(sensing_ratio, smooth_plot_among_psi, 'b', label = r"Among different $\Psi$")
plt.fill_between(sensing_ratio, (y-ci), (y+ci), color='blue', alpha = 0.1)
plt.plot(sensing_ratio, smooth_plot_ground_truth, 'g', label = "w.r.t Ground Truth")
plt.title("F-Score vs Sensing Ratio")
plt.xlabel("Sensing Ratio (in %)")
plt.ylabel("F-Score")
plt.ylim([0.6, 1.0])
plt.legend()
plt.savefig("./../Plots/synthetic_fscore_vs_sr.png")
plt.show()
