# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
from numpy.linalg import matrix_power as MP

import random
import scipy
from scipy.spatial.distance import cdist
from scipy.io import savemat, loadmat

import networkx as nx
import sys

import tensorflow as tf
from keras.callbacks import EarlyStopping

# %%
print(f"TF Version: {tf.__version__}")
# Out:
# TF Version: 2.14.0

# %%
X_train = np.array(loadmat('./Dataset/X_train.mat')['X'])
N, T = X_train.shape

print(N, T)
# Out:
# 32 744

# %%
plt.hist(np.array(X_train).flatten(), bins = 'auto')
plt.xlabel("X")
plt.ylabel("Count")
plt.title("Histogram of generated data")
plt.show()

# %%
dt = np.zeros([T - 1, T])

for i in range(T - 1):
    dt[i, i] = -1
    dt[i, i - 1] = 1

d = dt.T
d = np.concatenate((d, np.zeros([T, 1])), axis = 1) 
d[T - 1, T - 1] = -1
d = d.T
d[T - 1, T - 1] = 1 
d[-1, -2] = 1
d[0, -1] = 0

d = tf.convert_to_tensor(d, dtype = "float32")

Mul = np.eye(N) - np.ones([N, N])
Mul = tf.convert_to_tensor(Mul, dtype = "float32")

# %%
def initial_graph(X_training, N, top_values):
    distance_matrix = cdist(X_training, X_training, metric = 'euclidean')
    
    # top_values = 6
    sorted_indices = distance_matrix.argsort(1)
    TAdj = np.zeros([N, N])
    
    for i in range(N):
        for j in range(1, top_values):
            k = sorted_indices[i][j]
            TAdj[i][k] = 1
    
    TAdj = (TAdj + TAdj.T) / 2
    TAdj = np.where(TAdj > 0.1, 1, 0)
    
    Laplacian_init = np.diag(np.sum(TAdj, 1)) - TAdj
    
    return Laplacian_init

# %%
coeffs = 0
psi_cost = 0
Laplacian = 0
A_transform_cost = 0

model_pred = []
loss_model = []
learned_graph = []
mse_known_list = []
mse_unknown_list = []

# %%
coeffs_list = np.load("./Outputs/cost_func_coeffs.npy")
print(len(coeffs_list))
# Out:
# 80

# %%
# A - Target, B - Predicted
def costfunc(A, B):
    global coeffs
    global X_train
    global psi_cost
    global Laplacian
    global A_transform_cost

    B_tmp = tf.squeeze(B)
    data_fidelity = (tf.norm(tf.multiply(psi_cost, (X_train - B))) ** 2) * coeffs[0]
    smoothness = tf.linalg.trace(tf.transpose(B_tmp) @ Laplacian @ B_tmp @ A_transform_cost) * coeffs[1]
    L_cost = (tf.norm(Laplacian) ** 2) * coeffs[2]
    Z_cost = (tf.norm(A_transform_cost) ** 2) * coeffs[3]
    
    tmp = (smoothness) + (data_fidelity) + (L_cost) + (Z_cost)
    
    global loss_model
    loss_model.append(tmp)
    
    return tmp
    
def costfunc1(A, B):
    global X_train
    global psi_cost
    
    data_fidelity = (tf.norm(tf.multiply(psi_cost, (X_train - B))) ** 2)
    return (data_fidelity)

def costfunc2(A, B):
    global Laplacian
    global A_transform_cost
    
    B_tmp = tf.squeeze(B)
    smoothness = tf.linalg.trace(tf.transpose(B_tmp) @ Laplacian @ B_tmp @ A_transform_cost)
    
    return (smoothness)

def costfunc3(A, B):
    global Laplacian
    
    L_cost = (tf.norm(Laplacian) ** 2)
    
    return (L_cost)

def costfunc4(A, B):
    global A_transform_cost
    
    Z_cost = (tf.norm(A_transform_cost) ** 2)
    
    return (Z_cost)

# %%
def mse_unknown(A, B):
    
    global psi_cost
    psi = psi_cost
    
    psid = tf.convert_to_tensor(np.ones([N, T], dtype = float) - psi, dtype = "float32")
    mse_unk = (LA.norm(np.multiply(psid, (X_train - B))) ** 2) / np.sum(psid.numpy().flatten())
    
    global mse_unknown_list
    mse_unknown_list.append(mse_unk)
    
    return mse_unk

def mse_known(A, B):
    
    global psi_cost
    psi = psi_cost
    
    mse_kn = (LA.norm(np.multiply(psi, (X_train - B))) ** 2) / np.sum(psi.numpy().flatten())
    
    global model_pred
    model_pred.append([A.numpy(), B.numpy()])
    
    global mse_known_list
    mse_known_list.append(mse_kn)
    
    return mse_kn

# %%
callb = EarlyStopping(monitor = 'loss', mode = 'min', min_delta = 0.0001, verbose = 1, patience = 10)

# %%
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr / lr_decay_factor

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
class ProposedModel(tf.keras.Model):
    
    def __init__(self, L_init, reg_init, loops_init, d_init, p_init, alpha_init, beta_init, threshold_in, **kwargs):
        super(ProposedModel, self).__init__(**kwargs)
        
        self.p1_init = tf.constant(p_init[0], shape = (1, 1), dtype = "float32")
        self.p1 = tf.Variable(initial_value = self.p1_init, trainable = True, name = "p1")
        
        self.p2_init = tf.constant(p_init[1], shape = (1, 1), dtype = "float32")
        self.p2 = tf.Variable(initial_value = self.p2_init, trainable = True, name = "p2")
        
        self.L_in = L_init
        self.preg = reg_init
        self.loops = loops_init
        self.d_int = d_init
        self.alp = alpha_init
        self.bet = beta_init
        self.threshold_init = threshold_in
        
    def data_inpainting(self, psi, Y, Lk, AAT):
        loop_b, reg = self.loops[1], self.preg

        Xk = tf.zeros_like(Y)
        Zk = -(tf.multiply(psi, Xk) - Y + (2 * reg * (Lk @ Xk @ AAT)))
        
        for i in range(loop_b):
            fdx_xk = tf.multiply(psi, Xk) - Y + (2 * reg * (Lk @ Xk @ AAT))

            # row_print = 4
            # tmp = list(zip((tf.multiply(psi, Xk) - Y)[:, row_print].numpy(), (2 * reg * (Lk @ Xk @ AAT)[:, row_print].numpy())))
            # print("\n\nStart here")
            # for k in tmp:
            #     print(k)
            
            fdx_zk = tf.multiply(psi, Zk) - Y + (2 * reg * (Lk @ Zk @ AAT))
            
            tau = tf.linalg.trace(tf.transpose(fdx_xk) @ Zk) / tf.linalg.trace(tf.transpose((Y + fdx_zk)) @ Zk)
            
            Xk_1 = Xk - (tau * Zk)

            fdx_xk_1 = tf.multiply(psi, Xk_1) - Y + (2 * reg * (Lk @ Xk_1 @ AAT))
            gamma = (tf.norm(fdx_xk_1) ** 2) / (tf.norm(fdx_xk) ** 2)

            Zk_1 = (gamma * Zk) - fdx_xk_1

            Xk = Xk_1
            Zk = Zk_1
        # print("\n\nEnds here\n\n")
        return Xk_1
    
    def graph_learning(self, X, Lk, AAT):
        loop_c, alpha, beta = self.loops[2], self.alp, self.bet
        
        # Computing the smoothness term
        X_AAT_XT = tf.matmul(X, tf.matmul(AAT, tf.transpose(X)))
        
        for i in range(loop_c):

            # Extracting the adjacency matrix from the Laplacian
            adj_i = tf.multiply(Mul, Lk)

            # Computing the gradient with respect to laplacian
            fdL_Lk = X_AAT_XT + (beta * Lk)
            
            # row_print = 4
            # print("For beta")
            # tmp = list(zip(X_AAT_XT[row_print, :].numpy(), np.array(beta * Lk)[row_print, :]))
            # for k in tmp:
            #     print(k)
            
            # Extracting the adjacency matrix from the gradient
            adj_grad = tf.multiply(Mul, fdL_Lk)
            
            # Computing the new adjacency
            # tmp = list(zip(adj_i[row_print, :].numpy(), (alpha * adj_grad)[row_print, :].numpy()))
            # print("\nFor alpha")
            # for k in tmp:
            #     print(k)
            # print("\nStart here")
            
            adj_i1 = adj_i - (alpha * adj_grad)
            
            # Avoiding any negative values
            adj_i1 = tf.nn.relu(adj_i1)

            # Computing the new laplacian
            Lk_1 = tf.linalg.diag(tf.math.reduce_sum(adj_i1, 1)) - adj_i1
            
            # Updating the laplacian
            Lk = Lk_1
        # print("\n\nEnds here\n\n")
        return Lk
    

    def call(self, y):

        psi = y[0,:,T:]
        global psi_cost
        psi_cost = psi

        psi = tf.convert_to_tensor(psi, dtype = "float32")
        
        X_in = y[0,:,:T]
        X_in = psi * tf.convert_to_tensor(X_in, dtype = "float32")
        Y = X_in
        
        d = self.d_int
        LT = tf.matmul(d, tf.transpose(d))
        LT = tf.convert_to_tensor(LT, dtype = "float32")
        
        A_transform = tf.eye(T) + (self.p1 * MP(LT, 1)) + (self.p2 * MP(LT, 2))
        AAT = A_transform
        
        global A_transform_cost
        A_transform_cost = AAT
        
        loop_a = self.loops[0]
        threshold = self.threshold_init
        Lk = self.L_in
        
        for i in range(loop_a):
            
            Xk_1 = self.data_inpainting(psi, Y, Lk, AAT)
            
            Xk_1_gt = X_in + tf.multiply((tf.ones(psi.shape) - psi), Xk_1)
            
            Lk_1 = self.graph_learning(Xk_1_gt, Lk, AAT)
            
            Adj = tf.linalg.diag(tf.linalg.diag_part(Lk_1)) - Lk_1 # Gives adjacency
            
            n = tf.math.count_nonzero(Adj, dtype="float32")
            mean = tf.math.reduce_sum(Adj) / n
            Adj = tf.math.subtract(Adj, (threshold * mean)) # Ensures the sparsity of learned graph
            
            Adj = tf.nn.relu(Adj)
            # Adj = tf.math.sign(Adj)
            
            Lk_1 = tf.linalg.diag(tf.math.reduce_sum(Adj, 1)) - Adj
            
            Lk = Lk_1
        
            global Laplacian
            Laplacian = Lk
        
        Xk_1 = self.data_inpainting(psi, Y, Lk, AAT)
        
        global learned_graph
        learned_graph.append(Lk.numpy())
        
        return tf.reshape(Xk_1, [1, N, T])

# %%
Lap_init = initial_graph(X_train, N, 10)

loop_a = 5
loop_b = 20 # Data Inpainting
loop_c = 10 # Graph Learning

reg_init = 1.0e-7

alpha_init = 5.0e-5
beta_init = 1.0e2

threshold_init = 0.3

no_of_psi = 10
sensing_ratio = np.arange(1.0, 81.0, 1.0) / 100.0

p_init = [10.0, 10.0]

lr_decay_factor = 1.04

all_psi = []
all_vars = []

# %%
for i_sen, rem in enumerate(sensing_ratio):
    
    print(f"\n\n###########################################################################################")
    print(f"################################### Sensing Ratio: {rem * 100}% ###################################")
    print(f"###########################################################################################\n\n")
    
    if i_sen == 0:
        M = int(rem * T)
        X_train_missing = np.zeros([no_of_psi, N, T])
        X_train_concatenated = np.zeros([no_of_psi, N, 2*T])
    
        for i in range(no_of_psi):
            psi_k = np.array([0] * (N * M) + [1] * (N * (T - M)))
            np.random.shuffle(psi_k)
            psi_k = psi_k.reshape([N, T])
            all_psi.append(psi_k)
            X_train_missing[i, : , : ] = X_train * psi_k
            X_train_concatenated[i, :, :] = np.concatenate((X_train_missing[i], psi_k), axis = 1)

    else:
        previous_psi = all_psi[-no_of_psi : ]
        X_train_missing = np.zeros([no_of_psi, N, T])
        X_train_concatenated = np.zeros([no_of_psi, N, 2 * T])
        
        rem_diff = int(N * (rem - sensing_ratio[i_sen - 1]) * T)
        
        for i in range(no_of_psi):
            psi_k_tmp = np.array(previous_psi[i]).flatten()
            ones_idx = np.where(psi_k_tmp == 1)
            
            ones_to_zero_idx = np.random.choice(ones_idx[0], size = rem_diff)
            psi_k_tmp[ones_to_zero_idx] = 0
            psi_k = psi_k_tmp
            
            psi_k = psi_k.reshape([N, T])
            all_psi.append(psi_k)
            X_train_missing[i, : , : ] = X_train * psi_k
            X_train_concatenated[i, :, :] = np.concatenate((X_train_missing[i], psi_k), axis = 1)
    
    coeffs = coeffs_list[i_sen, : ]
    
    sgd_optimizer = tf.keras.optimizers.SGD(learning_rate = 1.0e-2, momentum = 0.01)
    
    our_model = ProposedModel(Lap_init, reg_init, [loop_a, loop_b, loop_c], 
                              d, p_init, alpha_init, beta_init, threshold_init, name = 'our')
    our_model.compile(optimizer = sgd_optimizer, loss = costfunc,
                      metrics = [mse_known, mse_unknown], run_eagerly=True)
    
    our_model.fit(X_train_concatenated, X_train_missing, epochs = 30, 
                  callbacks = [lr_scheduler], batch_size = 1)
    
    var = our_model.variables
    var_lst = []
    for v in var:
        var_lst.append(v.numpy()[0, 0])
    print(f"\nFilter Coefficients:", var_lst)
    all_vars.append(var_lst)
# Out:
# ###########################################################################################
# ################################### Sensing Ratio: 1.0% ###################################
# ###########################################################################################
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/30
# 10/10 [==============================] - 15s 1s/step - loss: 14.4870 - mse_known: 2.9769e-06 - mse_unknown: 0.4937 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.1378 - mse_known: 2.8719e-06 - mse_unknown: 0.4926 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.7971 - mse_known: 2.7709e-06 - mse_unknown: 0.4917 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 15s 1s/step - loss: 13.4652 - mse_known: 2.6730e-06 - mse_unknown: 0.4907 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.1410 - mse_known: 2.5786e-06 - mse_unknown: 0.4896 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.8248 - mse_known: 2.4872e-06 - mse_unknown: 0.4884 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.5164 - mse_known: 2.3994e-06 - mse_unknown: 0.4871 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.2156 - mse_known: 2.3138e-06 - mse_unknown: 0.4857 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.9222 - mse_known: 2.2322e-06 - mse_unknown: 0.4840 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.6360 - mse_known: 2.1530e-06 - mse_unknown: 0.4824 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.3571 - mse_known: 2.0769e-06 - mse_unknown: 0.4803 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.0848 - mse_known: 2.0032e-06 - mse_unknown: 0.4781 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.8192 - mse_known: 1.9318e-06 - mse_unknown: 0.4761 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.5601 - mse_known: 1.8635e-06 - mse_unknown: 0.4741 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.3073 - mse_known: 1.7970e-06 - mse_unknown: 0.4720 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.0607 - mse_known: 1.7332e-06 - mse_unknown: 0.4699 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.8202 - mse_known: 1.6711e-06 - mse_unknown: 0.4680 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.5856 - mse_known: 1.6116e-06 - mse_unknown: 0.4661 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.3566 - mse_known: 1.5539e-06 - mse_unknown: 0.4641 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.1337 - mse_known: 1.4981e-06 - mse_unknown: 0.4623 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.9195 - mse_known: 1.4453e-06 - mse_unknown: 0.4604 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.7187 - mse_known: 1.3962e-06 - mse_unknown: 0.4587 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.5298 - mse_known: 1.3503e-06 - mse_unknown: 0.4569 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.3522 - mse_known: 1.3077e-06 - mse_unknown: 0.4554 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.1852 - mse_known: 1.2677e-06 - mse_unknown: 0.4539 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.0277 - mse_known: 1.2303e-06 - mse_unknown: 0.4525 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.8792 - mse_known: 1.1957e-06 - mse_unknown: 0.4510 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.7391 - mse_known: 1.1631e-06 - mse_unknown: 0.4497 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.6068 - mse_known: 1.1324e-06 - mse_unknown: 0.4485 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.4818 - mse_known: 1.1036e-06 - mse_unknown: 0.4474 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.3517, 5.801799]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 2.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.4199 - mse_known: 2.9572e-06 - mse_unknown: 0.4472 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.0730 - mse_known: 2.8559e-06 - mse_unknown: 0.4463 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.7347 - mse_known: 2.7587e-06 - mse_unknown: 0.4455 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.4047 - mse_known: 2.6660e-06 - mse_unknown: 0.4449 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.0827 - mse_known: 2.5730e-06 - mse_unknown: 0.4437 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.7684 - mse_known: 2.4855e-06 - mse_unknown: 0.4430 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.4620 - mse_known: 2.4012e-06 - mse_unknown: 0.4420 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.1632 - mse_known: 2.3189e-06 - mse_unknown: 0.4412 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.8717 - mse_known: 2.2353e-06 - mse_unknown: 0.4399 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.5877 - mse_known: 2.1572e-06 - mse_unknown: 0.4389 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.3107 - mse_known: 2.0819e-06 - mse_unknown: 0.4374 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.0401 - mse_known: 2.0069e-06 - mse_unknown: 0.4364 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.7764 - mse_known: 1.9357e-06 - mse_unknown: 0.4350 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.5189 - mse_known: 1.8640e-06 - mse_unknown: 0.4340 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.2679 - mse_known: 1.8002e-06 - mse_unknown: 0.4328 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.0229 - mse_known: 1.7361e-06 - mse_unknown: 0.4314 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.7841 - mse_known: 1.6748e-06 - mse_unknown: 0.4303 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.5509 - mse_known: 1.6145e-06 - mse_unknown: 0.4296 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.3234 - mse_known: 1.5561e-06 - mse_unknown: 0.4283 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.1014 - mse_known: 1.5008e-06 - mse_unknown: 0.4269 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.8886 - mse_known: 1.4470e-06 - mse_unknown: 0.4256 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.6889 - mse_known: 1.3971e-06 - mse_unknown: 0.4242 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.5015 - mse_known: 1.3516e-06 - mse_unknown: 0.4234 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.3250 - mse_known: 1.3085e-06 - mse_unknown: 0.4226 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.1590 - mse_known: 1.2682e-06 - mse_unknown: 0.4208 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.0021 - mse_known: 1.2319e-06 - mse_unknown: 0.4202 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.8543 - mse_known: 1.1958e-06 - mse_unknown: 0.4187 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.7150 - mse_known: 1.1633e-06 - mse_unknown: 0.4186 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.5833 - mse_known: 1.1331e-06 - mse_unknown: 0.4175 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.4589 - mse_known: 1.1048e-06 - mse_unknown: 0.4165 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.358205, 5.8142004]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 3.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.3496 - mse_known: 2.9215e-06 - mse_unknown: 0.4499 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.0049 - mse_known: 2.8204e-06 - mse_unknown: 0.4487 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.6686 - mse_known: 2.7241e-06 - mse_unknown: 0.4478 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.3406 - mse_known: 2.6305e-06 - mse_unknown: 0.4468 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.0206 - mse_known: 2.5409e-06 - mse_unknown: 0.4456 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.7083 - mse_known: 2.4548e-06 - mse_unknown: 0.4445 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.4038 - mse_known: 2.3694e-06 - mse_unknown: 0.4431 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.1071 - mse_known: 2.2887e-06 - mse_unknown: 0.4419 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.8174 - mse_known: 2.2120e-06 - mse_unknown: 0.4406 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.5349 - mse_known: 2.1349e-06 - mse_unknown: 0.4392 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.2595 - mse_known: 2.0629e-06 - mse_unknown: 0.4375 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.9911 - mse_known: 1.9944e-06 - mse_unknown: 0.4362 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.7292 - mse_known: 1.9283e-06 - mse_unknown: 0.4347 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.4734 - mse_known: 1.8590e-06 - mse_unknown: 0.4330 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.2238 - mse_known: 1.7948e-06 - mse_unknown: 0.4315 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.9806 - mse_known: 1.7306e-06 - mse_unknown: 0.4304 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.7432 - mse_known: 1.6718e-06 - mse_unknown: 0.4288 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.5117 - mse_known: 1.6116e-06 - mse_unknown: 0.4274 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.2857 - mse_known: 1.5570e-06 - mse_unknown: 0.4260 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.0651 - mse_known: 1.5013e-06 - mse_unknown: 0.4253 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.8537 - mse_known: 1.4484e-06 - mse_unknown: 0.4243 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.6551 - mse_known: 1.3994e-06 - mse_unknown: 0.4229 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.4685 - mse_known: 1.3564e-06 - mse_unknown: 0.4222 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.2933 - mse_known: 1.3117e-06 - mse_unknown: 0.4210 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.1280 - mse_known: 1.2731e-06 - mse_unknown: 0.4199 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.9721 - mse_known: 1.2356e-06 - mse_unknown: 0.4190 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.8253 - mse_known: 1.2017e-06 - mse_unknown: 0.4177 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.6869 - mse_known: 1.1687e-06 - mse_unknown: 0.4175 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.5565 - mse_known: 1.1379e-06 - mse_unknown: 0.4160 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.4329 - mse_known: 1.1105e-06 - mse_unknown: 0.4159 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.365, 5.8268986]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 4.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.2822 - mse_known: 2.8947e-06 - mse_unknown: 0.4699 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.9398 - mse_known: 2.7944e-06 - mse_unknown: 0.4687 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.6058 - mse_known: 2.6977e-06 - mse_unknown: 0.4671 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.2799 - mse_known: 2.6042e-06 - mse_unknown: 0.4657 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.9621 - mse_known: 2.5135e-06 - mse_unknown: 0.4642 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.6522 - mse_known: 2.4262e-06 - mse_unknown: 0.4626 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.3497 - mse_known: 2.3425e-06 - mse_unknown: 0.4609 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.0545 - mse_known: 2.2615e-06 - mse_unknown: 0.4593 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.7675 - mse_known: 2.1843e-06 - mse_unknown: 0.4577 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.4867 - mse_known: 2.1093e-06 - mse_unknown: 0.4554 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.2128 - mse_known: 2.0354e-06 - mse_unknown: 0.4535 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.9456 - mse_known: 1.9647e-06 - mse_unknown: 0.4514 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.6849 - mse_known: 1.8980e-06 - mse_unknown: 0.4495 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.4306 - mse_known: 1.8316e-06 - mse_unknown: 0.4477 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.1825 - mse_known: 1.7685e-06 - mse_unknown: 0.4457 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.9405 - mse_known: 1.7070e-06 - mse_unknown: 0.4440 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.7049 - mse_known: 1.6482e-06 - mse_unknown: 0.4420 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.4745 - mse_known: 1.5907e-06 - mse_unknown: 0.4400 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.2497 - mse_known: 1.5341e-06 - mse_unknown: 0.4382 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.0305 - mse_known: 1.4824e-06 - mse_unknown: 0.4367 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.8207 - mse_known: 1.4310e-06 - mse_unknown: 0.4349 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.6234 - mse_known: 1.3850e-06 - mse_unknown: 0.4333 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.4379 - mse_known: 1.3394e-06 - mse_unknown: 0.4319 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.2635 - mse_known: 1.2985e-06 - mse_unknown: 0.4306 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.0991 - mse_known: 1.2598e-06 - mse_unknown: 0.4291 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.9443 - mse_known: 1.2244e-06 - mse_unknown: 0.4280 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.7985 - mse_known: 1.1900e-06 - mse_unknown: 0.4266 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.6607 - mse_known: 1.1591e-06 - mse_unknown: 0.4254 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.5308 - mse_known: 1.1293e-06 - mse_unknown: 0.4244 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.4080 - mse_known: 1.1010e-06 - mse_unknown: 0.4230 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.371551, 5.839122]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 5.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.2155 - mse_known: 2.8703e-06 - mse_unknown: 0.4735 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.8751 - mse_known: 2.7712e-06 - mse_unknown: 0.4723 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.5432 - mse_known: 2.6751e-06 - mse_unknown: 0.4711 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.2199 - mse_known: 2.5823e-06 - mse_unknown: 0.4696 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 17s 2s/step - loss: 12.9042 - mse_known: 2.4927e-06 - mse_unknown: 0.4682 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 16s 2s/step - loss: 12.5960 - mse_known: 2.4059e-06 - mse_unknown: 0.4666 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 2s/step - loss: 12.2954 - mse_known: 2.3227e-06 - mse_unknown: 0.4652 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.0020 - mse_known: 2.2420e-06 - mse_unknown: 0.4636 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.7162 - mse_known: 2.1639e-06 - mse_unknown: 0.4621 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.4371 - mse_known: 2.0891e-06 - mse_unknown: 0.4606 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.1648 - mse_known: 2.0165e-06 - mse_unknown: 0.4587 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.8991 - mse_known: 1.9466e-06 - mse_unknown: 0.4572 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.6400 - mse_known: 1.8785e-06 - mse_unknown: 0.4556 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.3872 - mse_known: 1.8139e-06 - mse_unknown: 0.4539 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.1407 - mse_known: 1.7495e-06 - mse_unknown: 0.4521 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.9000 - mse_known: 1.6888e-06 - mse_unknown: 0.4502 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.6655 - mse_known: 1.6302e-06 - mse_unknown: 0.4488 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.4366 - mse_known: 1.5732e-06 - mse_unknown: 0.4470 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.2133 - mse_known: 1.5189e-06 - mse_unknown: 0.4454 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.9954 - mse_known: 1.4655e-06 - mse_unknown: 0.4438 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.7866 - mse_known: 1.4147e-06 - mse_unknown: 0.4422 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.5905 - mse_known: 1.3676e-06 - mse_unknown: 0.4408 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.4063 - mse_known: 1.3248e-06 - mse_unknown: 0.4391 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.2329 - mse_known: 1.2835e-06 - mse_unknown: 0.4377 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.0696 - mse_known: 1.2457e-06 - mse_unknown: 0.4364 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.9157 - mse_known: 1.2108e-06 - mse_unknown: 0.4353 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.7707 - mse_known: 1.1763e-06 - mse_unknown: 0.4340 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.6336 - mse_known: 1.1460e-06 - mse_unknown: 0.4328 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.5044 - mse_known: 1.1164e-06 - mse_unknown: 0.4320 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.3822 - mse_known: 1.0892e-06 - mse_unknown: 0.4308 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.378041, 5.850911]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 6.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.1363 - mse_known: 2.8300e-06 - mse_unknown: 0.4793 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.7987 - mse_known: 2.7322e-06 - mse_unknown: 0.4780 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.4697 - mse_known: 2.6379e-06 - mse_unknown: 0.4767 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.1484 - mse_known: 2.5466e-06 - mse_unknown: 0.4754 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.8351 - mse_known: 2.4582e-06 - mse_unknown: 0.4742 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.5292 - mse_known: 2.3732e-06 - mse_unknown: 0.4729 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.2312 - mse_known: 2.2913e-06 - mse_unknown: 0.4714 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.9402 - mse_known: 2.2114e-06 - mse_unknown: 0.4700 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.6563 - mse_known: 2.1351e-06 - mse_unknown: 0.4684 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.3793 - mse_known: 2.0612e-06 - mse_unknown: 0.4670 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.1091 - mse_known: 1.9894e-06 - mse_unknown: 0.4653 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.8455 - mse_known: 1.9201e-06 - mse_unknown: 0.4638 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.5886 - mse_known: 1.8532e-06 - mse_unknown: 0.4622 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.3379 - mse_known: 1.7885e-06 - mse_unknown: 0.4606 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.0934 - mse_known: 1.7269e-06 - mse_unknown: 0.4589 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.8550 - mse_known: 1.6668e-06 - mse_unknown: 0.4575 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.6219 - mse_known: 1.6087e-06 - mse_unknown: 0.4561 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.3948 - mse_known: 1.5528e-06 - mse_unknown: 0.4546 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.1732 - mse_known: 1.4983e-06 - mse_unknown: 0.4529 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 15s 2s/step - loss: 8.9569 - mse_known: 1.4460e-06 - mse_unknown: 0.4513 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.7494 - mse_known: 1.3963e-06 - mse_unknown: 0.4496 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.5545 - mse_known: 1.3500e-06 - mse_unknown: 0.4482 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.3715 - mse_known: 1.3067e-06 - mse_unknown: 0.4468 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.1991 - mse_known: 1.2660e-06 - mse_unknown: 0.4455 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.0370 - mse_known: 1.2285e-06 - mse_unknown: 0.4442 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.8840 - mse_known: 1.1931e-06 - mse_unknown: 0.4429 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.7400 - mse_known: 1.1601e-06 - mse_unknown: 0.4417 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.6041 - mse_known: 1.1299e-06 - mse_unknown: 0.4406 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.4757 - mse_known: 1.1003e-06 - mse_unknown: 0.4394 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.3545 - mse_known: 1.0731e-06 - mse_unknown: 0.4383 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.385792, 5.865807]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 7.000000000000001% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 14.0665 - mse_known: 2.8049e-06 - mse_unknown: 0.4955 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.7312 - mse_known: 2.7082e-06 - mse_unknown: 0.4942 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 15s 1s/step - loss: 13.4039 - mse_known: 2.6148e-06 - mse_unknown: 0.4930 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 15s 1s/step - loss: 13.0846 - mse_known: 2.5242e-06 - mse_unknown: 0.4916 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.7733 - mse_known: 2.4370e-06 - mse_unknown: 0.4903 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.4694 - mse_known: 2.3525e-06 - mse_unknown: 0.4890 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.1730 - mse_known: 2.2709e-06 - mse_unknown: 0.4875 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.8841 - mse_known: 2.1924e-06 - mse_unknown: 0.4860 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.6026 - mse_known: 2.1169e-06 - mse_unknown: 0.4843 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.3274 - mse_known: 2.0436e-06 - mse_unknown: 0.4827 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.0590 - mse_known: 1.9730e-06 - mse_unknown: 0.4811 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.7971 - mse_known: 1.9044e-06 - mse_unknown: 0.4794 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.5418 - mse_known: 1.8384e-06 - mse_unknown: 0.4775 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.2929 - mse_known: 1.7748e-06 - mse_unknown: 0.4758 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.0497 - mse_known: 1.7129e-06 - mse_unknown: 0.4740 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.8124 - mse_known: 1.6536e-06 - mse_unknown: 0.4723 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.5812 - mse_known: 1.5960e-06 - mse_unknown: 0.4706 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.3553 - mse_known: 1.5401e-06 - mse_unknown: 0.4689 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.1350 - mse_known: 1.4862e-06 - mse_unknown: 0.4672 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.9200 - mse_known: 1.4345e-06 - mse_unknown: 0.4656 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.7138 - mse_known: 1.3854e-06 - mse_unknown: 0.4640 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.5205 - mse_known: 1.3390e-06 - mse_unknown: 0.4623 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.3385 - mse_known: 1.2968e-06 - mse_unknown: 0.4609 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.1674 - mse_known: 1.2569e-06 - mse_unknown: 0.4595 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.0063 - mse_known: 1.2192e-06 - mse_unknown: 0.4582 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.8545 - mse_known: 1.1849e-06 - mse_unknown: 0.4570 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.7113 - mse_known: 1.1518e-06 - mse_unknown: 0.4557 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.5765 - mse_known: 1.1214e-06 - mse_unknown: 0.4545 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.4489 - mse_known: 1.0927e-06 - mse_unknown: 0.4534 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.3284 - mse_known: 1.0660e-06 - mse_unknown: 0.4522 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.392759, 5.8782806]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 8.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.9955 - mse_known: 2.7776e-06 - mse_unknown: 0.5031 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.6623 - mse_known: 2.6818e-06 - mse_unknown: 0.5018 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.3373 - mse_known: 2.5895e-06 - mse_unknown: 0.5004 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.0204 - mse_known: 2.5003e-06 - mse_unknown: 0.4991 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.7112 - mse_known: 2.4142e-06 - mse_unknown: 0.4974 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.4095 - mse_known: 2.3310e-06 - mse_unknown: 0.4959 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.1152 - mse_known: 2.2505e-06 - mse_unknown: 0.4945 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.8283 - mse_known: 2.1730e-06 - mse_unknown: 0.4929 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.5482 - mse_known: 2.0980e-06 - mse_unknown: 0.4913 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.2749 - mse_known: 2.0253e-06 - mse_unknown: 0.4898 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.0082 - mse_known: 1.9552e-06 - mse_unknown: 0.4882 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.7481 - mse_known: 1.8874e-06 - mse_unknown: 0.4865 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.4946 - mse_known: 1.8224e-06 - mse_unknown: 0.4846 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.2470 - mse_known: 1.7591e-06 - mse_unknown: 0.4830 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.0054 - mse_known: 1.6981e-06 - mse_unknown: 0.4814 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.7697 - mse_known: 1.6391e-06 - mse_unknown: 0.4796 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.5397 - mse_known: 1.5820e-06 - mse_unknown: 0.4779 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.3154 - mse_known: 1.5269e-06 - mse_unknown: 0.4763 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.0965 - mse_known: 1.4737e-06 - mse_unknown: 0.4746 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.8830 - mse_known: 1.4222e-06 - mse_unknown: 0.4729 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.6782 - mse_known: 1.3734e-06 - mse_unknown: 0.4711 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.4859 - mse_known: 1.3281e-06 - mse_unknown: 0.4697 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.3053 - mse_known: 1.2857e-06 - mse_unknown: 0.4681 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.1353 - mse_known: 1.2465e-06 - mse_unknown: 0.4666 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.9753 - mse_known: 1.2094e-06 - mse_unknown: 0.4653 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.8243 - mse_known: 1.1747e-06 - mse_unknown: 0.4640 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.6821 - mse_known: 1.1426e-06 - mse_unknown: 0.4628 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.5480 - mse_known: 1.1125e-06 - mse_unknown: 0.4616 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.4213 - mse_known: 1.0843e-06 - mse_unknown: 0.4605 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.3016 - mse_known: 1.0576e-06 - mse_unknown: 0.4594 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.400097, 5.8918905]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 9.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 15s 1s/step - loss: 13.9239 - mse_known: 2.7461e-06 - mse_unknown: 0.5117 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.5935 - mse_known: 2.6520e-06 - mse_unknown: 0.5103 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.2712 - mse_known: 2.5615e-06 - mse_unknown: 0.5088 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.9561 - mse_known: 2.4731e-06 - mse_unknown: 0.5073 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.6490 - mse_known: 2.3881e-06 - mse_unknown: 0.5059 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.3493 - mse_known: 2.3060e-06 - mse_unknown: 0.5044 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.0569 - mse_known: 2.2266e-06 - mse_unknown: 0.5027 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.7717 - mse_known: 2.1502e-06 - mse_unknown: 0.5012 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.4934 - mse_known: 2.0761e-06 - mse_unknown: 0.4995 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.2220 - mse_known: 2.0046e-06 - mse_unknown: 0.4979 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.9571 - mse_known: 1.9355e-06 - mse_unknown: 0.4962 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.6987 - mse_known: 1.8686e-06 - mse_unknown: 0.4944 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.4466 - mse_known: 1.8041e-06 - mse_unknown: 0.4928 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.2006 - mse_known: 1.7416e-06 - mse_unknown: 0.4909 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.9606 - mse_known: 1.6814e-06 - mse_unknown: 0.4893 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.7265 - mse_known: 1.6231e-06 - mse_unknown: 0.4873 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.4980 - mse_known: 1.5668e-06 - mse_unknown: 0.4856 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.2752 - mse_known: 1.5124e-06 - mse_unknown: 0.4839 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.0577 - mse_known: 1.4599e-06 - mse_unknown: 0.4822 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.8455 - mse_known: 1.4092e-06 - mse_unknown: 0.4805 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.6421 - mse_known: 1.3610e-06 - mse_unknown: 0.4788 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.4509 - mse_known: 1.3159e-06 - mse_unknown: 0.4772 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.2716 - mse_known: 1.2741e-06 - mse_unknown: 0.4757 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 15s 1s/step - loss: 8.1024 - mse_known: 1.2351e-06 - mse_unknown: 0.4742 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.9434 - mse_known: 1.1986e-06 - mse_unknown: 0.4729 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.7936 - mse_known: 1.1646e-06 - mse_unknown: 0.4715 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.6523 - mse_known: 1.1328e-06 - mse_unknown: 0.4703 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.5190 - mse_known: 1.1030e-06 - mse_unknown: 0.4691 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.3931 - mse_known: 1.0749e-06 - mse_unknown: 0.4679 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 15s 1s/step - loss: 7.2742 - mse_known: 1.0487e-06 - mse_unknown: 0.4668 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.407407, 5.90447]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 10.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 15s 1s/step - loss: 13.8539 - mse_known: 2.7203e-06 - mse_unknown: 0.5150 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.5255 - mse_known: 2.6273e-06 - mse_unknown: 0.5136 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.2049 - mse_known: 2.5374e-06 - mse_unknown: 0.5122 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.8922 - mse_known: 2.4504e-06 - mse_unknown: 0.5106 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.5872 - mse_known: 2.3664e-06 - mse_unknown: 0.5091 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 15s 1s/step - loss: 12.2895 - mse_known: 2.2854e-06 - mse_unknown: 0.5075 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 11.9991 - mse_known: 2.2072e-06 - mse_unknown: 0.5061 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.7157 - mse_known: 2.1313e-06 - mse_unknown: 0.5046 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.4392 - mse_known: 2.0578e-06 - mse_unknown: 0.5031 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 11.1695 - mse_known: 1.9872e-06 - mse_unknown: 0.5016 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 15s 1s/step - loss: 10.9063 - mse_known: 1.9190e-06 - mse_unknown: 0.4999 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.6495 - mse_known: 1.8527e-06 - mse_unknown: 0.4984 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.3991 - mse_known: 1.7892e-06 - mse_unknown: 0.4968 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 10.1548 - mse_known: 1.7275e-06 - mse_unknown: 0.4952 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.9163 - mse_known: 1.6678e-06 - mse_unknown: 0.4937 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.6839 - mse_known: 1.6104e-06 - mse_unknown: 0.4920 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 15s 1s/step - loss: 9.4569 - mse_known: 1.5546e-06 - mse_unknown: 0.4905 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.2355 - mse_known: 1.5010e-06 - mse_unknown: 0.4887 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 9.0194 - mse_known: 1.4489e-06 - mse_unknown: 0.4871 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.8086 - mse_known: 1.3988e-06 - mse_unknown: 0.4855 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.6065 - mse_known: 1.3509e-06 - mse_unknown: 0.4839 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.4166 - mse_known: 1.3067e-06 - mse_unknown: 0.4823 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.2382 - mse_known: 1.2652e-06 - mse_unknown: 0.4809 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 8.0705 - mse_known: 1.2268e-06 - mse_unknown: 0.4794 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.9125 - mse_known: 1.1906e-06 - mse_unknown: 0.4782 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.7636 - mse_known: 1.1570e-06 - mse_unknown: 0.4769 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.6233 - mse_known: 1.1256e-06 - mse_unknown: 0.4757 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.4908 - mse_known: 1.0961e-06 - mse_unknown: 0.4745 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.3657 - mse_known: 1.0683e-06 - mse_unknown: 0.4734 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 7.2475 - mse_known: 1.0423e-06 - mse_unknown: 0.4723 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [8.414457, 5.917174]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 11.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.7782 - mse_known: 2.6868e-06 - mse_unknown: 0.5146 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.4523 - mse_known: 2.5953e-06 - mse_unknown: 0.5132 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 13.1343 - mse_known: 2.5066e-06 - mse_unknown: 0.5117 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 12.8240 - mse_known: 2.4211e-06 - mse_unknown: 0.5102 - lr: 0.0100
# Epoch 5/30
# ...
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 15981.9873 - mse_known: 0.0086 - mse_unknown: 2.5480 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 14381.4814 - mse_known: 0.0074 - mse_unknown: 2.6623 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 12775.2324 - mse_known: 0.0064 - mse_unknown: 2.7999 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 11119.7266 - mse_known: 0.0055 - mse_unknown: 2.9629 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 9346.1094 - mse_known: 0.0048 - mse_unknown: 3.1736 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 7406.5220 - mse_known: 0.0041 - mse_unknown: 3.4331 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 5176.1724 - mse_known: 0.0036 - mse_unknown: 3.7735 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 2189.1670 - mse_known: 0.0032 - mse_unknown: 4.2614 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: -4055.1750 - mse_known: 0.0035 - mse_unknown: 5.3226 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: -33743.6172 - mse_known: 0.2894 - mse_unknown: 5.0334 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [nan, nan]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 78.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 295.9440 - mse_known: 1.9959e-05 - mse_unknown: 2.3018 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 204.1300 - mse_known: 9.7966e-06 - mse_unknown: 2.1436 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 134.1169 - mse_known: 4.1880e-06 - mse_unknown: 1.8724 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 81.3330 - mse_known: 7.3968e-07 - mse_unknown: 1.4803 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 47.3946 - mse_known: 5.2998e-08 - mse_unknown: 1.1787 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 3901640.7500 - mse_known: 3.2340 - mse_unknown: 6.0560 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: 7703821.0000 - mse_known: 6.6229 - mse_unknown: 7.5833 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 7543347.0000 - mse_known: 6.5924 - mse_unknown: 7.5677 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 7386552.0000 - mse_known: 6.5625 - mse_unknown: 7.5525 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 7233405.5000 - mse_known: 6.5319 - mse_unknown: 7.5367 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 7083822.5000 - mse_known: 6.5009 - mse_unknown: 7.5208 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 6937717.0000 - mse_known: 6.4693 - mse_unknown: 7.5046 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 6795039.0000 - mse_known: 6.4373 - mse_unknown: 7.4881 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 6655649.5000 - mse_known: 6.4054 - mse_unknown: 7.4716 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 13s 1s/step - loss: 6519541.5000 - mse_known: 6.3730 - mse_unknown: 7.4549 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 6386577.5000 - mse_known: 6.3403 - mse_unknown: 7.4381 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 6256644.0000 - mse_known: 6.3084 - mse_unknown: 7.4214 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 6129689.0000 - mse_known: 6.2762 - mse_unknown: 7.4047 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 6005725.0000 - mse_known: 6.2429 - mse_unknown: 7.3873 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 5884611.0000 - mse_known: 6.2105 - mse_unknown: 7.3702 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 5768336.5000 - mse_known: 6.1782 - mse_unknown: 7.3533 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 5659025.0000 - mse_known: 6.1470 - mse_unknown: 7.3369 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 5556200.0000 - mse_known: 6.1164 - mse_unknown: 7.3208 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 5459369.5000 - mse_known: 6.0870 - mse_unknown: 7.3054 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 5368133.5000 - mse_known: 6.0588 - mse_unknown: 7.2904 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 5282153.0000 - mse_known: 6.0306 - mse_unknown: 7.2756 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 5200944.0000 - mse_known: 6.0044 - mse_unknown: 7.2617 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 5124267.5000 - mse_known: 5.9784 - mse_unknown: 7.2480 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 5051782.5000 - mse_known: 5.9535 - mse_unknown: 7.2347 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 4983257.5000 - mse_known: 5.9294 - mse_unknown: 7.2220 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [2172.4683, 8808.4]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 79.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 298.9810 - mse_known: 2.3814e-05 - mse_unknown: 2.3990 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 205.1154 - mse_known: 1.2173e-05 - mse_unknown: 2.2314 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 133.3945 - mse_known: 4.9717e-06 - mse_unknown: 1.9369 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 78.3136 - mse_known: 7.0762e-07 - mse_unknown: 1.4865 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 44.7988 - mse_known: 2.9358e-08 - mse_unknown: 1.1935 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: 3008.7612 - mse_known: 5.2003e-04 - mse_unknown: 3.2663 - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 15s 1s/step - loss: 4526.9014 - mse_known: 7.3503e-04 - mse_unknown: 2.3779 - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: 3830.3647 - mse_known: 5.7040e-04 - mse_unknown: 2.4217 - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: 3175.3757 - mse_known: 4.4008e-04 - mse_unknown: 2.4587 - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: 2576.2439 - mse_known: 3.3779e-04 - mse_unknown: 2.4866 - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: 2045.7405 - mse_known: 2.5680e-04 - mse_unknown: 2.5037 - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: 1592.1627 - mse_known: 1.9557e-04 - mse_unknown: 2.5079 - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: 1216.2302 - mse_known: 1.4692e-04 - mse_unknown: 2.4967 - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: 913.2131 - mse_known: 1.0806e-04 - mse_unknown: 2.4665 - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: 674.2272 - mse_known: 7.5660e-05 - mse_unknown: 2.4134 - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: 488.6789 - mse_known: 5.0107e-05 - mse_unknown: 2.3238 - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: 346.5426 - mse_known: 3.0014e-05 - mse_unknown: 2.1925 - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: 237.4770 - mse_known: 1.4583e-05 - mse_unknown: 1.9911 - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: 153.0483 - mse_known: 5.2584e-06 - mse_unknown: 1.6615 - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: 90.0798 - mse_known: 5.7353e-07 - mse_unknown: 1.2388 - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: 58.9579 - mse_known: 1.7098e-07 - mse_unknown: 2.4366 - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: 1249183.3750 - mse_known: 3.0723 - mse_unknown: 5.5076 - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: 1235178.2500 - mse_known: 3.0432 - mse_unknown: 5.4873 - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: 1220395.2500 - mse_known: 3.0134 - mse_unknown: 5.4662 - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: 1206342.8750 - mse_known: 2.9834 - mse_unknown: 5.4449 - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: 1192972.0000 - mse_known: 2.9552 - mse_unknown: 5.4248 - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: 1180244.1250 - mse_known: 2.9280 - mse_unknown: 5.4055 - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 14s 1s/step - loss: 1168117.2500 - mse_known: 2.9021 - mse_unknown: 5.3868 - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: 1156557.6250 - mse_known: 2.8765 - mse_unknown: 5.3686 - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 14s 1s/step - loss: 1145532.7500 - mse_known: 2.8528 - mse_unknown: 5.3515 - lr: 0.0068
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Filter Coefficients: [922.17694, 3299.3857]
#
#
# ###########################################################################################
# ################################### Sensing Ratio: 80.0% ###################################
# ###########################################################################################
#
#
# Epoch 1/30
# 10/10 [==============================] - 14s 1s/step - loss: 303.3881 - mse_known: 2.8219e-05 - mse_unknown: 2.4847 - lr: 0.0100
# Epoch 2/30
# 10/10 [==============================] - 14s 1s/step - loss: 206.5360 - mse_known: 1.5334e-05 - mse_unknown: 2.3065 - lr: 0.0100
# Epoch 3/30
# 10/10 [==============================] - 14s 1s/step - loss: 133.5699 - mse_known: 6.5953e-06 - mse_unknown: 2.0008 - lr: 0.0100
# Epoch 4/30
# 10/10 [==============================] - 14s 1s/step - loss: 78.0754 - mse_known: 9.0439e-07 - mse_unknown: 1.5193 - lr: 0.0100
# Epoch 5/30
# 10/10 [==============================] - 14s 1s/step - loss: 43.3762 - mse_known: 4.5983e-08 - mse_unknown: 1.2223 - lr: 0.0100
# Epoch 6/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 7/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 8/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 9/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 10/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 11/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 12/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 13/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 14/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 15/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 16/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 17/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 18/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 19/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 20/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0100
# Epoch 21/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0096
# Epoch 22/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0092
# Epoch 23/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0089
# Epoch 24/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0085
# Epoch 25/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0082
# Epoch 26/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0079
# Epoch 27/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0076
# Epoch 28/30
# 10/10 [==============================] - 13s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0073
# Epoch 29/30
# 10/10 [==============================] - 14s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0070
# Epoch 30/30
# 10/10 [==============================] - 15s 1s/step - loss: nan - mse_known: nan - mse_unknown: nan - lr: 0.0068
#
# Filter Coefficients: [nan, nan]

# %%
for i, v in enumerate(all_vars):
    print(f"For {int(100 * sensing_ratio[i])}% sensing ratio: ", v)
# Out:
# For 1% sensing ratio:  [8.3517, 5.801799]
# For 2% sensing ratio:  [8.358205, 5.8142004]
# For 3% sensing ratio:  [8.365, 5.8268986]
# For 4% sensing ratio:  [8.371551, 5.839122]
# For 5% sensing ratio:  [8.378041, 5.850911]
# For 6% sensing ratio:  [8.385792, 5.865807]
# For 7% sensing ratio:  [8.392759, 5.8782806]
# For 8% sensing ratio:  [8.400097, 5.8918905]
# For 9% sensing ratio:  [8.407407, 5.90447]
# For 10% sensing ratio:  [8.414457, 5.917174]
# For 11% sensing ratio:  [8.42228, 5.9309993]
# For 12% sensing ratio:  [8.428832, 5.9427447]
# For 13% sensing ratio:  [8.436525, 5.9565444]
# For 14% sensing ratio:  [8.442606, 5.9681187]
# For 15% sensing ratio:  [8.450091, 5.982527]
# For 16% sensing ratio:  [8.456509, 5.9924583]
# For 17% sensing ratio:  [8.462502, 6.0035305]
# For 18% sensing ratio:  [8.468984, 6.0137944]
# For 19% sensing ratio:  [8.475142, 6.023821]
# For 20% sensing ratio:  [8.482299, 6.036373]
# For 21% sensing ratio:  [8.489148, 6.046811]
# For 22% sensing ratio:  [8.494651, 6.055466]
# For 23% sensing ratio:  [4.4406986, 0.83086354]
# For 24% sensing ratio:  [8.508363, 6.077692]
# For 25% sensing ratio:  [8.514445, 6.0883126]
# For 26% sensing ratio:  [4.566954, 1.1106136]
# For 27% sensing ratio:  [4.609628, 1.2086251]
# For 28% sensing ratio:  [4.6566005, 1.3062426]
# For 28% sensing ratio:  [4.6943893, 1.3803743]
# For 30% sensing ratio:  [4.73945, 1.4622667]
# For 31% sensing ratio:  [4.787139, 1.548796]
# For 32% sensing ratio:  [4.8319597, 1.632014]
# For 33% sensing ratio:  [4.875748, 1.7153342]
# For 34% sensing ratio:  [4.9262033, 1.7914004]
# For 35% sensing ratio:  [4.970886, 1.8643674]
# For 36% sensing ratio:  [5.009054, 1.9247053]
# For 37% sensing ratio:  [5.051513, 1.982054]
# For 38% sensing ratio:  [5.0980654, 2.0419111]
# For 39% sensing ratio:  [5.1394744, 2.1069922]
# For 40% sensing ratio:  [5.187905, 2.16331]
# For 41% sensing ratio:  [5.238191, 2.2214944]
# For 42% sensing ratio:  [5.2835374, 2.2606876]
# For 43% sensing ratio:  [5.3301277, 2.3259256]
# For 44% sensing ratio:  [5.3662214, 2.3432002]
# For 45% sensing ratio:  [5.4274635, 2.407378]
# For 46% sensing ratio:  [5.475921, 2.4630685]
# For 47% sensing ratio:  [5.5222964, 2.5014005]
# For 48% sensing ratio:  [5.571188, 2.5540397]
# For 49% sensing ratio:  [5.6091785, 2.555123]
# For 50% sensing ratio:  [5.6497083, 2.5885766]
# For 51% sensing ratio:  [5.7026277, 2.6423438]
# For 52% sensing ratio:  [5.747124, 2.6759114]
# For 53% sensing ratio:  [5.787375, 2.6781762]
# For 54% sensing ratio:  [5.827334, 2.6841505]
# For 55% sensing ratio:  [5.858137, 2.668868]
# For 56% sensing ratio:  [5.898504, 2.6834233]
# For 56% sensing ratio:  [5.9414907, 2.690837]
# For 57% sensing ratio:  [5.9873624, 2.67645]
# For 59% sensing ratio:  [6.0178113, 2.6601622]
# For 60% sensing ratio:  [6.055284, 2.671076]
# For 61% sensing ratio:  [6.07575, 2.640309]
# For 62% sensing ratio:  [6.102517, 2.6328456]
# For 63% sensing ratio:  [6.1293573, 2.6006148]
# For 64% sensing ratio:  [6.144058, 2.5439827]
# For 65% sensing ratio:  [6.1572948, 2.4896111]
# For 66% sensing ratio:  [6.175718, 2.4370303]
# For 67% sensing ratio:  [nan, nan]
# For 68% sensing ratio:  [6.2093563, 2.320732]
# For 69% sensing ratio:  [6.195992, 2.1861513]
# For 70% sensing ratio:  [52050.242, 212958.98]
# For 71% sensing ratio:  [nan, nan]
# For 72% sensing ratio:  [nan, nan]
# For 73% sensing ratio:  [nan, nan]
# For 74% sensing ratio:  [nan, nan]
# For 75% sensing ratio:  [nan, nan]
# For 76% sensing ratio:  [407812.62, 1460622.1]
# For 77% sensing ratio:  [nan, nan]
# For 78% sensing ratio:  [2172.4683, 8808.4]
# For 79% sensing ratio:  [922.17694, 3299.3857]
# For 80% sensing ratio:  [nan, nan]

# %%
np.save('./Outputs/loss_model.npy', loss_model)
np.save('./Outputs/learned_graph.npy', learned_graph)
np.save('./Outputs/mse_known.npy', mse_known_list)
np.save('./Outputs/mse_unknown.npy', mse_unknown_list)
